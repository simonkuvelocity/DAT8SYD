# %% [markdown]
# # Data Science Part Time Course
#
# ## Week 5 - Lesson 2 - Lab: Databases with Python
#
# In this Lab the goal is connect to a database (created form a local file), read the data into Python and interact with it.

# %% [markdown]
# ## 1. Data import
#
# Connect to the file 'assets/datasets/enron.db' using one of these methods:
#
# - sqlite3 python package
# - pandas.read_sql
# - SQLite Manager Firefox extension
#
# Take a look at the database and query the master table. How many Tables are there in the db?
#
# > Answer:
# There are 3 tables:
# - MessageBase
# - RecipientBase
# - EmployeeBase

# %%
import sqlite3
conn = sqlite3.connect('enron.db') 
c = conn.cursor()
c.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
# Out:
# [('MessageBase',), ('RecipientBase',), ('EmployeeBase',)]

# %% [markdown]
# Query the `sqlite_master` table to retrieve the **schema** of the `EmployeeBase` table.
#
# 1. What fields are there?
# 1. What's the type of each of them?

# %%
fields = c.execute("SELECT sql from sqlite_master WHERE type='table' and name='MessageBase';").fetchall()
print (''.join(fields[0]))

fields = c.execute("SELECT sql from sqlite_master WHERE type='table' and name='RecipientBase';").fetchall()
print (''.join(fields[0]))

fields = c.execute("SELECT sql from sqlite_master WHERE type='table' and name='EmployeeBase';").fetchall()
print (''.join(fields[0]))
# Out:
# CREATE TABLE MessageBase (
#     mid INTEGER,
#     filename TEXT,
#     unix_time INTEGER,
#     subject TEXT,
#     from_eid INTEGER,
#
#     PRIMARY KEY(mid ASC),
#     FOREIGN KEY(from_eid) REFERENCES Employee(eid)
# )
# CREATE TABLE RecipientBase (
#     mid INTEGER,
#     rno INTEGER,
#     to_eid INTEGER,
#
#     PRIMARY KEY(mid ASC, rno ASC)
#     FOREIGN KEY(mid) REFERENCES Message(mid)
#     FOREIGN KEY(to_eid) REFERENCES Employee(eid)
# )
# CREATE TABLE EmployeeBase (
#                   [eid] INTEGER,
#   [name] TEXT,
#   [department] TEXT,
#   [longdepartment] TEXT,
#   [title] TEXT,
#   [gender] TEXT,
#   [seniority] TEXT
#
#                   )

# %% [markdown]
# 1. Print the first 5 rows of EmployeeBase table
# 1. Print the first 5 rows of MessageBase table
# 1. Print the first 5 rows of RecipientBase table
#
# **Hint**  use `SELECT` and `LIMIT`.

# %%
results = c.execute("SELECT * FROM EmployeeBase LIMIT 5;").fetchall()
for row in results:
    print (row)
# Out:
# (1, 'John Arnold', 'Forestry', 'ENA Gas Financial', 'VP Trading', 'Male', 'Senior')
# (2, 'Harry Arora', 'Forestry', 'ENA East Power', 'VP Trading', 'Male', 'Senior')
# (3, 'Robert Badeer', 'Forestry', 'ENA West Power', 'Mgr Trading', 'Male', 'Junior')
# (4, 'Susan Bailey', 'Legal', 'ENA Legal', 'Specialist Legal', 'Female', 'Junior')
# (5, 'Eric Bass', 'Forestry', 'ENA Gas Texas', 'Trader', 'Male', 'Junior')

# %%
results = c.execute("SELECT * FROM MessageBase LIMIT 5;").fetchall()
for row in results:
    print (row)
# Out:
# (1, 'taylor-m/sent/11', 910930020, 'Cd$ CME letter', 138)
# (2, 'taylor-m/sent/17', 911459940, 'Indemnification', 138)
# (3, 'taylor-m/sent/18', 911463840, 'Re: Indemnification', 138)
# (4, 'taylor-m/sent/23', 911874180, 'Re: Coral Energy, L.P.', 138)
# (5, 'taylor-m/sent/27', 912396120, 'Bankruptcy Code revisions', 138)

# %%
results = c.execute("SELECT * FROM RecipientBase LIMIT 10;").fetchall()
for row in results:
    print (row)
    
# The first field is message id, the second is recipient number, and the third is the id of the recipient.
# mid, rno, to_eid
# Out:
# (1, 1, 59)
# (2, 1, 15)
# (3, 1, 15)
# (4, 1, 109)
# (4, 2, 49)
# (4, 3, 120)
# (4, 4, 59)
# (5, 1, 45)
# (5, 2, 53)
# (6, 1, 113)

# %% [markdown]
# Now try other SQL statements on the local database, such as SELECT .... FROM ... WHERE ....
#
# For example, print the records of EmployeeBase where the Gender is male

# %%
results = c.execute("SELECT * FROM EmployeeBase where Gender='Male';").fetchall()
for row in results:
    print (row)
# Out:
# (1, 'John Arnold', 'Forestry', 'ENA Gas Financial', 'VP Trading', 'Male', 'Senior')
# (2, 'Harry Arora', 'Forestry', 'ENA East Power', 'VP Trading', 'Male', 'Senior')
# (3, 'Robert Badeer', 'Forestry', 'ENA West Power', 'Mgr Trading', 'Male', 'Junior')
# (5, 'Eric Bass', 'Forestry', 'ENA Gas Texas', 'Trader', 'Male', 'Junior')
# (6, 'Don Baughman Jr.', 'Forestry', 'ENA East Power', 'Mgr Trading', 'Male', 'Junior')
# (8, 'Robert Benson', 'Forestry', 'ENA East Power', 'Dir Trading', 'Male', 'Senior')
# (11, 'Rick Buy', 'Forestry', 'Enron', 'VP & CRO', 'Male', 'Senior')
# (12, 'Larry Campbell', 'Other', 'ETS', 'Specialist', 'Male', 'Junior')
# (13, 'Larry F. Campbell', 'Other', 'ENA East Power', 'Specialist', 'Male', 'Junior')
# (14, 'Mike Carson', 'Forestry', 'ENA East Power', 'Mgr Trading', 'Male', 'Junior')
# (18, 'Sean Crandall', 'Forestry', 'ENA West Power', 'Dir Trading', 'Male', 'Senior')
# (19, 'Martin Cuilla', 'Forestry', 'ENA Gas Central', 'Mgr Trading', 'Male', 'Junior')
# ...

# %% [markdown]
# #### Import each of the 3 tables to a Pandas Dataframes

# %%
import pandas as pd
employees = pd.read_sql("SELECT * FROM EmployeeBase;", conn)
recipients = pd.read_sql("SELECT * FROM RecipientBase;", conn)
messages = pd.read_sql("SELECT * FROM MessageBase;", conn)

# %%
recipients.head(10)
# Out:
#    mid  rno  to_eid
# 0    1    1      59
# 1    2    1      15
# 2    3    1      15
# 3    4    1     109
# 4    4    2      49
# 5    4    3     120
# 6    4    4      59
# 7    5    1      45
# 8    5    2      53
# 9    6    1     113

# %% [markdown]
# ## 2. Data Exploration
#
# Use the 3 dataframes to answer the following questions:
#
# 1. How many employees are there in the company?
# - How many messages are there in the database?
# - Some messages are sent to more than one recipient. Group the messages by message_id and count the number of recepients. Then look at the distribution of recepient numbers.
#     - How many messages have only one recepient?
#     - How many messages have >= 5 recepients?
#     - What's the highest number of recepients?
#     - Who sent the message with the highest number of recepients?
# - Plot the distribution of recepient numbers using Bokeh.

# %%
 pd.read_sql("SELECT count(*) FROM EmployeeBase;", conn)
# Out:
#    count(*)
# 0       156

# %%
 pd.read_sql("SELECT count(*) FROM MessageBase;", conn)
# Out:
#    count(*)
# 0     21635

# %%
messages.head()
pd.read_sql("SELECT mid, count(*) FROM MessageBase group by mid;", conn)
# Out:
#          mid  count(*)
# 0          1         1
# 1          2         1
# 2          3         1
# 3          4         1
# 4          5         1
# 5          6         1
# 6          7         1
# 7          8         1
# 8          9         1
# 9         10         1
# 10        11         1
# 11        12         1
# 12        13         1
# 13        14         1
# 14        15         1
# 15        16         1
# 16        17         1
# 17        18         1
# 18        19         1
# 19        20         1
# 20        21         1
# 21        22         1
# 22        23         1
# 23        24         1
# 24        25         1
# 25        26         1
# 26        27         1
# 27        28         1
# 28        29         1
# 29        30         1
# ...      ...       ...
# 21605  21606         1
# 21606  21607         1
# 21607  21608         1
# 21608  21609         1
# 21609  21610         1
# 21610  21611         1
# 21611  21612         1
# 21612  21613         1
# ...

# %%
pd.read_sql("SELECT mid, count(*) as cnt FROM RecipientBase group by mid having cnt=1;", conn)
# Out:
#          mid  cnt
# 0          1    1
# 1          2    1
# 2          3    1
# 3          6    1
# 4          7    1
# 5          8    1
# 6          9    1
# 7         10    1
# 8         11    1
# 9         13    1
# 10        14    1
# 11        15    1
# 12        18    1
# 13        19    1
# 14        20    1
# 15        21    1
# 16        22    1
# 17        23    1
# 18        24    1
# 19        26    1
# 20        29    1
# 21        30    1
# 22        31    1
# 23        32    1
# 24        34    1
# 25        35    1
# 26        36    1
# 27        37    1
# 28        38    1
# 29        39    1
# ...      ...  ...
# 14955  21599    1
# 14956  21600    1
# 14957  21601    1
# 14958  21602    1
# 14959  21603    1
# 14960  21604    1
# 14961  21605    1
# 14962  21606    1
# 14963  21607    1
# 14964  21608    1
# 14965  21609    1
# 14966  21610    1
# 14967  21611    1
# 14968  21612    1
# 14969  21613    1
# 14970  21614    1
# 14971  21615    1
# 14972  21616    1
# ...

# %%
pd.read_sql("SELECT mid, count(*) as cnt FROM RecipientBase group by mid having cnt>=5;", conn)
# Out:
#         mid  cnt
# 0        28   13
# 1       109    5
# 2       117    5
# 3       121    5
# 4       122    6
# 5       125    5
# 6       173    5
# 7       174    5
# 8       178    5
# 9       180    5
# 10      196    5
# 11      207    5
# 12      272    5
# 13      275    5
# 14      280    5
# 15      291    5
# 16      313    5
# 17      322    6
# 18      331    5
# 19      374    5
# 20      376    5
# 21      392    5
# 22      396   10
# 23      399   10
# 24      411    5
# 25      418    5
# 26      425    5
# 27      457    5
# 28      473    5
# 29      520    5
# ...     ...  ...
# 1350  21028    6
# 1351  21030   15
# 1352  21034    7
# 1353  21036    5
# 1354  21039    5
# 1355  21047   19
# 1356  21068    5
# 1357  21093    5
# 1358  21103   20
# 1359  21168    5
# 1360  21225    6
# 1361  21242    5
# 1362  21323    5
# 1363  21324    6
# 1364  21332    5
# 1365  21335    5
# 1366  21341    7
# 1367  21360    5
# 1368  21365    5
# 1369  21398    5
# ...

# %%
pd.read_sql("SELECT mid, count(*) as cnt FROM RecipientBase group by mid order by cnt;", conn)
# Out:
#          mid  cnt
# 0          1    1
# 1          2    1
# 2          3    1
# 3          6    1
# 4          7    1
# 5          8    1
# 6          9    1
# 7         10    1
# 8         11    1
# 9         13    1
# 10        14    1
# 11        15    1
# 12        18    1
# 13        19    1
# 14        20    1
# 15        21    1
# 16        22    1
# 17        23    1
# 18        24    1
# 19        26    1
# 20        29    1
# 21        30    1
# 22        31    1
# 23        32    1
# 24        34    1
# 25        35    1
# 26        36    1
# 27        37    1
# 28        38    1
# 29        39    1
# ...      ...  ...
# 21605  15698   15
# 21606  15845   15
# 21607  15878   15
# 21608  15897   15
# 21609  16248   15
# 21610  19546   15
# 21611  21030   15
# 21612  11492   16
# 21613  11516   16
# 21614  12584   16
# 21615  14194   16
# 21616  14457   16
# 21617  14547   16
# 21618  18305   16
# 21619  19028   16
# 21620  21628   16
# 21621   6495   17
# 21622  10087   17
# ...

# %%
dist=pd.read_sql("SELECT mid, count(*) as cnt FROM RecipientBase group by mid ;", conn)

# %% [markdown]
# ## 3. Data Merging
#
# Use the pandas merge function to combine the information in the 3 dataframes to answer the following questions:
#
# 1. Are there more Men or Women employees?
# - How is gender distributed across departments?
# - Who is sending more emails? Men or Women?
# - What's the average number of emails sent by each gender?
# - Are there more Juniors or Seniors?
# - Who is sending more emails? Juniors or Seniors?
# - Which department is sending more emails? How does that relate with the number of employees in the department?
# - Who are the top 3 senders of emails? (people who sent out the most emails)

# %%
import sqlite3
conn = sqlite3.connect('enron.db') 
c = conn.cursor()
c.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()

import pandas as pd
employees = pd.read_sql("SELECT * FROM EmployeeBase;", conn)
recipients = pd.read_sql("SELECT * FROM RecipientBase;", conn)
messages = pd.read_sql("SELECT * FROM MessageBase;", conn)

fields = c.execute("SELECT sql from sqlite_master WHERE type='table' and name='MessageBase';").fetchall()
print (''.join(fields[0]))

fields = c.execute("SELECT sql from sqlite_master WHERE type='table' and name='RecipientBase';").fetchall()
print (''.join(fields[0]))

fields = c.execute("SELECT sql from sqlite_master WHERE type='table' and name='EmployeeBase';").fetchall()
print (''.join(fields[0]))
# Out:
# CREATE TABLE MessageBase (
#     mid INTEGER,
#     filename TEXT,
#     unix_time INTEGER,
#     subject TEXT,
#     from_eid INTEGER,
#
#     PRIMARY KEY(mid ASC),
#     FOREIGN KEY(from_eid) REFERENCES Employee(eid)
# )
# CREATE TABLE RecipientBase (
#     mid INTEGER,
#     rno INTEGER,
#     to_eid INTEGER,
#
#     PRIMARY KEY(mid ASC, rno ASC)
#     FOREIGN KEY(mid) REFERENCES Message(mid)
#     FOREIGN KEY(to_eid) REFERENCES Employee(eid)
# )
# CREATE TABLE EmployeeBase (
#                   [eid] INTEGER,
#   [name] TEXT,
#   [department] TEXT,
#   [longdepartment] TEXT,
#   [title] TEXT,
#   [gender] TEXT,
#   [seniority] TEXT
#
#                   )

# %%
# 1. Are there more Men or Women employees?
pd.read_sql("SELECT gender, count(*) as cnt FROM EmployeeBase  group by gender;", conn)
# Out:
#    gender  cnt
# 0  Female   43
# 1    Male  113

# %%
# 2. How is gender distributed across departments?
pd.read_sql("SELECT gender,department, count(*) as cnt FROM EmployeeBase  group by gender,department;", conn)
# Out:
#    gender department  cnt
# 0  Female   Forestry   10
# 1  Female      Legal   13
# 2  Female      Other   20
# 3    Male   Forestry   50
# 4    Male      Legal   12
# 5    Male      Other   51

# %%
# 3. Who is sending more emails? Men or Women?
pd.read_sql("SELECT gender, count(*) as cnt FROM EmployeeBase a join MessageBase  b where a.eid=b.from_eid group by gender;", conn)
# Out:
#    gender    cnt
# 0  Female   8794
# 1    Male  12841

# %%
# 4. What's the average number of emails sent by each gender?
print(8794/43)
print(12841/113)
# Out:
# 204.51162790697674
# 113.63716814159292

# %%
# 5. Are there more Juniors or Seniors?
pd.read_sql("SELECT seniority, count(*) as cnt FROM EmployeeBase  group by seniority;", conn)
# Out:
#   seniority  cnt
# 0    Junior   82
# 1    Senior   74

# %%
# 6. Who is sending more emails? Juniors or Seniors?
pd.read_sql("SELECT seniority, count(*) as cnt FROM EmployeeBase a join MessageBase  b where a.eid=b.from_eid group by seniority;", conn)
# Out:
#   seniority    cnt
# 0    Junior   9196
# 1    Senior  12439

# %%
# 7. Which department is sending more emails? How does that relate with the number of employees in the department?
pd.read_sql("SELECT department, count(*) as cnt FROM EmployeeBase a join MessageBase  b where a.eid=b.from_eid group by department;", conn)
# Out:
#   department    cnt
# 0   Forestry   4387
# 1      Legal  10396
# 2      Other   6852

# %%
# 7. How does that relate with the number of employees in the department?
pd.read_sql("SELECT department, count(*) as cnt FROM EmployeeBase  group by department;", conn)
# Out:
#   department  cnt
# 0   Forestry   60
# 1      Legal   25
# 2      Other   71

# %%
# 7. 
print(4387/60)
print(10396/25)
print(6852/71)
# Out:
# 73.11666666666666
# 415.84
# 96.50704225352112

# %%
# 8. Who are the top 3 senders of emails? (people who sent out the most emails)

pd.read_sql("SELECT eid, name, department,count(*) as cnt FROM EmployeeBase a join MessageBase  b where a.eid=b.from_eid group by eid , name, department order by cnt desc limit 3;", conn)
# Out:
#    eid             name department   cnt
# 0   20    Jeff Dasovich      Legal  1597
# 1   59       Tana Jones      Legal  1379
# 2  120  Sara Shackleton      Legal  1142
